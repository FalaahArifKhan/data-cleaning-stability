# %% [markdown]
# # Visualizations for Models

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "data-cleaning-stability":
    os.chdir("../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability

# %%
from source.visualizations.models_viz import create_box_plots_for_diff_imputers_and_models_exp1
from configs.constants import (ACS_INCOME_DATASET, LAW_SCHOOL_DATASET, GERMAN_CREDIT_DATASET,
                               CARDIOVASCULAR_DISEASE_DATASET, BANK_MARKETING_DATASET, DIABETES_DATASET, ErrorRepairMethod)

# %% [markdown]
# ## Initialize Configs

# %%
DATASET_NAME = DIABETES_DATASET
DATASETS_SENSITIVE_ATTRS = {
    ACS_INCOME_DATASET: ['SEX', 'RAC1P', 'SEX&RAC1P'],
    LAW_SCHOOL_DATASET: ['male', 'race', 'male&race'],
    GERMAN_CREDIT_DATASET: ['sex', 'age', 'sex&age'],
    CARDIOVASCULAR_DISEASE_DATASET: ['gender'],
    BANK_MARKETING_DATASET: ['age'],
    DIABETES_DATASET: ['Gender'],
}
SENSITIVE_ATTR_FOR_DISPARITY_METRICS = DATASETS_SENSITIVE_ATTRS[DATASET_NAME][-1]

# %%
from source.custom_classes.database_client import DatabaseClient

db_client = DatabaseClient()
db_client.connect()

# %% [markdown]
# ## Metric Visualizations

# %% [markdown]
# ### Overall Metrics

# %%
create_box_plots_for_diff_imputers_and_models_exp1(dataset_name=DATASET_NAME,
                                                   metric_name='accuracy',
                                                   db_client=db_client,
                                                   evaluation_scenarios=['exp1_mcar3', 'exp1_mar3', 'exp1_mnar3'])
# Out:
# Prepared a plot for exp1_mcar3
# Prepared a plot for exp1_mar3
# Prepared a plot for exp1_mnar3
# alt.VConcatChart(...)

# %%
create_box_plots_for_diff_imputers_and_models_exp1(dataset_name=DATASET_NAME,
                                                   metric_name='f1',
                                                   db_client=db_client,
                                                   evaluation_scenarios=['exp1_mcar3', 'exp1_mar3', 'exp1_mnar3'])
# Out:
# Prepared a plot for exp1_mcar3
# Prepared a plot for exp1_mar3
# Prepared a plot for exp1_mnar3
# alt.VConcatChart(...)

# %%
create_box_plots_for_diff_imputers_and_models_exp1(dataset_name=DATASET_NAME,
                                                   metric_name='label_stability',
                                                   db_client=db_client,
                                                   evaluation_scenarios=['exp1_mcar3', 'exp1_mar3', 'exp1_mnar3'])
# Out:
# Prepared a plot for exp1_mcar3
# Prepared a plot for exp1_mar3
# Prepared a plot for exp1_mnar3
# alt.VConcatChart(...)

# %%
create_box_plots_for_diff_imputers_and_models_exp1(dataset_name=DATASET_NAME,
                                                   metric_name='aleatoric_uncertainty',
                                                   db_client=db_client,
                                                   evaluation_scenarios=['exp1_mcar3', 'exp1_mar3', 'exp1_mnar3'])
# Out:
# Prepared a plot for exp1_mcar3
# Prepared a plot for exp1_mar3
# Prepared a plot for exp1_mnar3
# alt.VConcatChart(...)

# %%
create_box_plots_for_diff_imputers_and_models_exp1(dataset_name=DATASET_NAME,
                                                   metric_name='std',
                                                   db_client=db_client,
                                                   evaluation_scenarios=['exp1_mcar3', 'exp1_mar3', 'exp1_mnar3'])
# Out:
# Prepared a plot for exp1_mcar3
# Prepared a plot for exp1_mar3
# Prepared a plot for exp1_mnar3
# alt.VConcatChart(...)

# %% [markdown]
# ### Disparity Metrics

# %%
create_box_plots_for_diff_imputers_and_models_exp1(dataset_name=DATASET_NAME,
                                                   metric_name='Equalized_Odds_FPR',
                                                   group=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
                                                   db_client=db_client,
                                                   evaluation_scenarios=['exp1_mcar3', 'exp1_mar3', 'exp1_mnar3'])
# Out:
# Prepared a plot for exp1_mcar3
# Prepared a plot for exp1_mar3
# Prepared a plot for exp1_mnar3
# alt.VConcatChart(...)

# %%
create_box_plots_for_diff_imputers_and_models_exp1(dataset_name=DATASET_NAME,
                                                   metric_name='Equalized_Odds_FNR',
                                                   group=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
                                                   db_client=db_client,
                                                   evaluation_scenarios=['exp1_mcar3', 'exp1_mar3', 'exp1_mnar3'])
# Out:
# Prepared a plot for exp1_mcar3
# Prepared a plot for exp1_mar3
# Prepared a plot for exp1_mnar3
# alt.VConcatChart(...)

# %%
create_box_plots_for_diff_imputers_and_models_exp1(dataset_name=DATASET_NAME,
                                                   metric_name='Disparate_Impact',
                                                   group=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
                                                   db_client=db_client,
                                                   evaluation_scenarios=['exp1_mcar3', 'exp1_mar3', 'exp1_mnar3'])
# Out:
# Prepared a plot for exp1_mcar3
# Prepared a plot for exp1_mar3
# Prepared a plot for exp1_mnar3
# alt.VConcatChart(...)

# %%
create_box_plots_for_diff_imputers_and_models_exp1(dataset_name=DATASET_NAME,
                                                   metric_name='Label_Stability_Difference',
                                                   group=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
                                                   db_client=db_client,
                                                   evaluation_scenarios=['exp1_mcar3', 'exp1_mar3', 'exp1_mnar3'])
# Out:
# Prepared a plot for exp1_mcar3
# Prepared a plot for exp1_mar3
# Prepared a plot for exp1_mnar3
# alt.VConcatChart(...)

# %%
create_box_plots_for_diff_imputers_and_models_exp1(dataset_name=DATASET_NAME,
                                                   metric_name='Aleatoric_Uncertainty_Difference',
                                                   group=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
                                                   db_client=db_client,
                                                   evaluation_scenarios=['exp1_mcar3', 'exp1_mar3', 'exp1_mnar3'])
# Out:
# Prepared a plot for exp1_mcar3
# Prepared a plot for exp1_mar3
# Prepared a plot for exp1_mnar3
# alt.VConcatChart(...)

# %%
create_box_plots_for_diff_imputers_and_models_exp1(dataset_name=DATASET_NAME,
                                                   metric_name='Std_Difference',
                                                   group=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
                                                   db_client=db_client,
                                                   evaluation_scenarios=['exp1_mcar3', 'exp1_mar3', 'exp1_mnar3'])
# Out:
# Prepared a plot for exp1_mcar3
# Prepared a plot for exp1_mar3
# Prepared a plot for exp1_mnar3
# alt.VConcatChart(...)

# %%
db_client.close()
