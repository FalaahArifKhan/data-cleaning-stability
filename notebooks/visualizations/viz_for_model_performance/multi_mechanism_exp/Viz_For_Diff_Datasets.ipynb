# %% [markdown]
# # Visualizations for Different Datasets

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "data-cleaning-stability":
    os.chdir("../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability

# %%
from source.visualizations.models_viz import create_box_plots_for_diff_imputers_and_datasets
from configs.constants import (ACS_INCOME_DATASET, LAW_SCHOOL_DATASET, GERMAN_CREDIT_DATASET,
                               CARDIOVASCULAR_DISEASE_DATASET, BANK_MARKETING_DATASET, DIABETES_DATASET, ErrorRepairMethod)

# %% [markdown]
# ## Initialize Configs

# %%
DATASETS_ALL_SENSITIVE_ATTRS = {
    ACS_INCOME_DATASET: ['SEX', 'RAC1P', 'SEX&RAC1P'],
    LAW_SCHOOL_DATASET: ['male', 'race', 'male&race'],
    GERMAN_CREDIT_DATASET: ['sex', 'age', 'sex&age'],
    CARDIOVASCULAR_DISEASE_DATASET: ['gender'],
    BANK_MARKETING_DATASET: ['age'],
    DIABETES_DATASET: ['Gender'],
}
DATASETS_SENSITIVE_ATTRS = {
    ACS_INCOME_DATASET: 'SEX&RAC1P',
    LAW_SCHOOL_DATASET: 'male&race',
    GERMAN_CREDIT_DATASET: 'sex',
    CARDIOVASCULAR_DISEASE_DATASET: 'gender',
    BANK_MARKETING_DATASET: 'age',
    DIABETES_DATASET: 'Gender',
}

# %%
from source.custom_classes.database_client import DatabaseClient, get_secrets_path

db_client = DatabaseClient(secrets_path=get_secrets_path('secrets_3.env'))
db_client.connect()

# %% [markdown]
# ## Metric Visualizations

# %% [markdown]
# ### Overall Metrics

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='mixed_exp',
                                                test_injection_scenario='MCAR1 & MAR1 & MNAR1',
                                                metric_name='accuracy',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'mixed_exp', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (48, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'mixed_exp', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (48, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'mixed_exp', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (48, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'mixed_exp', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (216, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'mixed_exp', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (90, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'mixed_exp', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (48, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for folk
# alt.FacetChart(...)

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='mixed_exp',
                                                test_injection_scenario='MCAR1 & MAR1 & MNAR1',
                                                metric_name='f1',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'mixed_exp', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (48, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'mixed_exp', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (48, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'mixed_exp', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (48, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'mixed_exp', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (216, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'mixed_exp', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (90, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'mixed_exp', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (48, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for folk
# alt.FacetChart(...)

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='mixed_exp',
                                                test_injection_scenario='MCAR1 & MAR1 & MNAR1',
                                                metric_name='label_stability',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'mixed_exp', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (48, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'mixed_exp', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (48, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'mixed_exp', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (48, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'mixed_exp', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (216, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'mixed_exp', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (90, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'mixed_exp', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (48, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for folk
# alt.FacetChart(...)

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='mixed_exp',
                                                test_injection_scenario='MCAR1 & MAR1 & MNAR1',
                                                metric_name='aleatoric_uncertainty',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'mixed_exp', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (42, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'mixed_exp', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (42, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'mixed_exp', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (42, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'mixed_exp', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (210, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'mixed_exp', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (84, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'mixed_exp', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (42, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for folk
# alt.FacetChart(...)

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='mixed_exp',
                                                test_injection_scenario='MCAR1 & MAR1 & MNAR1',
                                                metric_name='std',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'mixed_exp', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (42, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'mixed_exp', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (42, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'mixed_exp', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (42, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'mixed_exp', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (210, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'mixed_exp', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (84, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'mixed_exp', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (42, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for folk
# alt.FacetChart(...)

# %% [markdown]
# ### Disparity Metrics

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='mixed_exp',
                                                test_injection_scenario='MCAR1 & MAR1 & MNAR1',
                                                dataset_to_group=DATASETS_SENSITIVE_ATTRS,
                                                metric_name='Equalized_Odds_TNR',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'mixed_exp', 'metric': 'TNR', 'subgroup': 'sex_dis', 'tag': 'OK'}
# query: {'dataset_name': 'german', 'evaluation_scenario': 'mixed_exp', 'metric': 'TNR', 'subgroup': 'sex_priv', 'tag': 'OK'}
# models_metric_df.shape: (48, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'mixed_exp', 'metric': 'TNR', 'subgroup': 'age_dis', 'tag': 'OK'}
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'mixed_exp', 'metric': 'TNR', 'subgroup': 'age_priv', 'tag': 'OK'}
# models_metric_df.shape: (48, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'mixed_exp', 'metric': 'TNR', 'subgroup': 'gender_dis', 'tag': 'OK'}
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'mixed_exp', 'metric': 'TNR', 'subgroup': 'gender_priv', 'tag': 'OK'}
# models_metric_df.shape: (48, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'mixed_exp', 'metric': 'TNR', 'subgroup': 'Gender_dis', 'tag': 'OK'}
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'mixed_exp', 'metric': 'TNR', 'subgroup': 'Gender_priv', 'tag': 'OK'}
# models_metric_df.shape: (216, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'mixed_exp', 'metric': 'TNR', 'subgroup': 'male&race_dis', 'tag': 'OK'}
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'mixed_exp', 'metric': 'TNR', 'subgroup': 'male&race_priv', 'tag': 'OK'}
# models_metric_df.shape: (90, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'mixed_exp', 'metric': 'TNR', 'subgroup': 'SEX&RAC1P_dis', 'tag': 'OK'}
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'mixed_exp', 'metric': 'TNR', 'subgroup': 'SEX&RAC1P_priv', 'tag': 'OK'}
# models_metric_df.shape: (48, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for folk
# alt.FacetChart(...)

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='mixed_exp',
                                                test_injection_scenario='MCAR1 & MAR1 & MNAR1',
                                                dataset_to_group=DATASETS_SENSITIVE_ATTRS,
                                                metric_name='Equalized_Odds_TPR',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'mixed_exp', 'metric': 'TPR', 'subgroup': 'sex_dis', 'tag': 'OK'}
# query: {'dataset_name': 'german', 'evaluation_scenario': 'mixed_exp', 'metric': 'TPR', 'subgroup': 'sex_priv', 'tag': 'OK'}
# models_metric_df.shape: (48, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'mixed_exp', 'metric': 'TPR', 'subgroup': 'age_dis', 'tag': 'OK'}
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'mixed_exp', 'metric': 'TPR', 'subgroup': 'age_priv', 'tag': 'OK'}
# models_metric_df.shape: (48, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'mixed_exp', 'metric': 'TPR', 'subgroup': 'gender_dis', 'tag': 'OK'}
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'mixed_exp', 'metric': 'TPR', 'subgroup': 'gender_priv', 'tag': 'OK'}
# models_metric_df.shape: (48, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'mixed_exp', 'metric': 'TPR', 'subgroup': 'Gender_dis', 'tag': 'OK'}
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'mixed_exp', 'metric': 'TPR', 'subgroup': 'Gender_priv', 'tag': 'OK'}
# models_metric_df.shape: (216, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'mixed_exp', 'metric': 'TPR', 'subgroup': 'male&race_dis', 'tag': 'OK'}
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'mixed_exp', 'metric': 'TPR', 'subgroup': 'male&race_priv', 'tag': 'OK'}
# models_metric_df.shape: (90, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'mixed_exp', 'metric': 'TPR', 'subgroup': 'SEX&RAC1P_dis', 'tag': 'OK'}
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'mixed_exp', 'metric': 'TPR', 'subgroup': 'SEX&RAC1P_priv', 'tag': 'OK'}
# models_metric_df.shape: (48, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for folk
# alt.FacetChart(...)

# %%
db_client.close()
