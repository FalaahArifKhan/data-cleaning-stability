# %% [markdown]
# # Visualizations for Different Datasets

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "data-cleaning-stability":
    os.chdir("../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability

# %%
from source.visualizations.models_viz import create_box_plots_for_diff_imputers_and_datasets
from configs.constants import (ACS_INCOME_DATASET, ACS_EMPLOYMENT_DATASET, LAW_SCHOOL_DATASET, GERMAN_CREDIT_DATASET,
                               CARDIOVASCULAR_DISEASE_DATASET, BANK_MARKETING_DATASET, DIABETES_DATASET, ErrorRepairMethod)

# %% [markdown]
# ## Initialize Configs

# %%
DATASETS_ALL_SENSITIVE_ATTRS = {
    ACS_INCOME_DATASET: ['SEX', 'RAC1P', 'SEX&RAC1P'],
    LAW_SCHOOL_DATASET: ['male', 'race', 'male&race'],
    GERMAN_CREDIT_DATASET: ['sex', 'age', 'sex&age'],
    CARDIOVASCULAR_DISEASE_DATASET: ['gender'],
    BANK_MARKETING_DATASET: ['age'],
    DIABETES_DATASET: ['Gender'],
    ACS_EMPLOYMENT_DATASET: ['SEX', 'RAC1P', 'SEX&RAC1P'],
}
DATASETS_SENSITIVE_ATTRS = {
    ACS_INCOME_DATASET: 'SEX&RAC1P',
    LAW_SCHOOL_DATASET: 'male&race',
    GERMAN_CREDIT_DATASET: 'sex',
    CARDIOVASCULAR_DISEASE_DATASET: 'gender',
    BANK_MARKETING_DATASET: 'age',
    DIABETES_DATASET: 'Gender',
    ACS_EMPLOYMENT_DATASET: 'SEX&RAC1P',
}

# %%
from source.custom_classes.database_client import DatabaseClient

db_client = DatabaseClient()
db_client.connect()

# %% [markdown]
# ## Metric Visualizations

# %% [markdown]
# ### Overall Metrics

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MNAR3',
                                                test_injection_scenario='MNAR3',
                                                metric_name='accuracy',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for folk
# query: {'dataset_name': 'folk_emp', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Accuracy', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (144, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for folk_emp
# alt.FacetChart(...)

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MCAR3',
                                                test_injection_scenario='MCAR3',
                                                metric_name='f1',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for folk
# query: {'dataset_name': 'folk_emp', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'F1', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (144, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for folk_emp
# alt.FacetChart(...)

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MNAR3',
                                                test_injection_scenario='MNAR3',
                                                metric_name='label_stability',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (774, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for folk
# query: {'dataset_name': 'folk_emp', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Label_Stability', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (144, 9)
# models_metric_df.shape: (48, 10)
# Extracted data for folk_emp
# alt.FacetChart(...)

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MCAR3',
                                                test_injection_scenario='MCAR3',
                                                metric_name='aleatoric_uncertainty',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (756, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (756, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (756, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (756, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (756, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (756, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for folk
# query: {'dataset_name': 'folk_emp', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Aleatoric_Uncertainty', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (126, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for folk_emp
# alt.FacetChart(...)

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MCAR3',
                                                test_injection_scenario='MCAR3',
                                                metric_name='std',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (756, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (756, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (756, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (756, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (756, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (756, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for folk
# query: {'dataset_name': 'folk_emp', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'Std', 'subgroup': 'overall', 'tag': 'OK'}
# models_metric_df.shape: (126, 9)
# models_metric_df.shape: (42, 10)
# Extracted data for folk_emp
# alt.FacetChart(...)

# %% [markdown]
# ### Disparity Metrics

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MNAR3',
                                                test_injection_scenario='MNAR3',
                                                dataset_to_group=DATASETS_SENSITIVE_ATTRS,
                                                metric_name='Equalized_Odds_TNR',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'sex_dis', 'tag': 'OK'}
# query: {'dataset_name': 'german', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'sex_priv', 'tag': 'OK'}
# models_metric_df.shape: (774, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'age_dis', 'tag': 'OK'}
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'age_priv', 'tag': 'OK'}
# models_metric_df.shape: (774, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'gender_dis', 'tag': 'OK'}
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'gender_priv', 'tag': 'OK'}
# models_metric_df.shape: (774, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'Gender_dis', 'tag': 'OK'}
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'Gender_priv', 'tag': 'OK'}
# models_metric_df.shape: (774, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'male&race_dis', 'tag': 'OK'}
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'male&race_priv', 'tag': 'OK'}
# models_metric_df.shape: (774, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'SEX&RAC1P_dis', 'tag': 'OK'}
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'SEX&RAC1P_priv', 'tag': 'OK'}
# models_metric_df.shape: (774, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for folk
# query: {'dataset_name': 'folk_emp', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'SEX&RAC1P_dis', 'tag': 'OK'}
# query: {'dataset_name': 'folk_emp', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'TNR', 'subgroup': 'SEX&RAC1P_priv', 'tag': 'OK'}
# models_metric_df.shape: (144, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for folk_emp
# alt.FacetChart(...)

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MCAR3',
                                                test_injection_scenario='MCAR3',
                                                dataset_to_group=DATASETS_SENSITIVE_ATTRS,
                                                metric_name='Equalized_Odds_FNR',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'sex_dis', 'tag': 'OK'}
# query: {'dataset_name': 'german', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'sex_priv', 'tag': 'OK'}
# models_metric_df.shape: (774, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'age_dis', 'tag': 'OK'}
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'age_priv', 'tag': 'OK'}
# models_metric_df.shape: (774, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'gender_dis', 'tag': 'OK'}
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'gender_priv', 'tag': 'OK'}
# models_metric_df.shape: (774, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'Gender_dis', 'tag': 'OK'}
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'Gender_priv', 'tag': 'OK'}
# models_metric_df.shape: (774, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'male&race_dis', 'tag': 'OK'}
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'male&race_priv', 'tag': 'OK'}
# models_metric_df.shape: (774, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'SEX&RAC1P_dis', 'tag': 'OK'}
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'SEX&RAC1P_priv', 'tag': 'OK'}
# models_metric_df.shape: (774, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for folk
# query: {'dataset_name': 'folk_emp', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'SEX&RAC1P_dis', 'tag': 'OK'}
# query: {'dataset_name': 'folk_emp', 'evaluation_scenario': 'exp1_mcar3', 'metric': 'FNR', 'subgroup': 'SEX&RAC1P_priv', 'tag': 'OK'}
# models_metric_df.shape: (144, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for folk_emp
# alt.FacetChart(...)

# %%
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MNAR3',
                                                test_injection_scenario='MNAR3',
                                                dataset_to_group=DATASETS_SENSITIVE_ATTRS,
                                                metric_name='Statistical_Parity_Difference',
                                                db_client=db_client)
# Out:
# query: {'dataset_name': 'german', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'sex_dis', 'tag': 'OK'}
# query: {'dataset_name': 'german', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'sex_priv', 'tag': 'OK'}
# models_metric_df.shape: (1548, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for german
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'age_dis', 'tag': 'OK'}
# query: {'dataset_name': 'bank', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'age_priv', 'tag': 'OK'}
# models_metric_df.shape: (1548, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for bank
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'gender_dis', 'tag': 'OK'}
# query: {'dataset_name': 'heart', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'gender_priv', 'tag': 'OK'}
# models_metric_df.shape: (1548, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for heart
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'Gender_dis', 'tag': 'OK'}
# query: {'dataset_name': 'diabetes', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'Gender_priv', 'tag': 'OK'}
# models_metric_df.shape: (1548, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for diabetes
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'male&race_dis', 'tag': 'OK'}
# query: {'dataset_name': 'law_school', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'male&race_priv', 'tag': 'OK'}
# models_metric_df.shape: (1548, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for law_school
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'SEX&RAC1P_dis', 'tag': 'OK'}
# query: {'dataset_name': 'folk', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'SEX&RAC1P_priv', 'tag': 'OK'}
# models_metric_df.shape: (1548, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for folk
# query: {'dataset_name': 'folk_emp', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'SEX&RAC1P_dis', 'tag': 'OK'}
# query: {'dataset_name': 'folk_emp', 'evaluation_scenario': 'exp1_mnar3', 'metric': 'Selection-Rate', 'subgroup': 'SEX&RAC1P_priv', 'tag': 'OK'}
# models_metric_df.shape: (288, 8)
# models_metric_df.shape: (48, 9)
# Extracted data for folk_emp
# alt.FacetChart(...)

# %%
db_client.close()
