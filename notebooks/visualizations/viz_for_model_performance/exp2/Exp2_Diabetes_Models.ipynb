# %% [markdown]
# # Visualizations for Diabetes Models

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "data-cleaning-stability":
    os.chdir("../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  c:\RAI\data-cleaning-stability

# %%
from source.visualizations.models_viz import create_exp2_line_bands_for_diff_imputers
from configs.constants import (ACS_INCOME_DATASET, LAW_SCHOOL_DATASET, GERMAN_CREDIT_DATASET,
                               CARDIOVASCULAR_DISEASE_DATASET, BANK_MARKETING_DATASET, DIABETES_DATASET, ErrorRepairMethod)

# %% [markdown]
# ## Initialize Configs

# %%
DATASET_NAME = DIABETES_DATASET
DATASETS_SENSITIVE_ATTRS = {
    ACS_INCOME_DATASET: ['SEX', 'RAC1P', 'SEX&RAC1P'],
    LAW_SCHOOL_DATASET: ['male', 'race', 'male&race'],
    GERMAN_CREDIT_DATASET: ['sex', 'age', 'sex&age'],
    CARDIOVASCULAR_DISEASE_DATASET: ['gender'],
    BANK_MARKETING_DATASET: ['age'],
    DIABETES_DATASET: ['Gender'],
}
SENSITIVE_ATTR_FOR_DISPARITY_METRICS = DATASETS_SENSITIVE_ATTRS[DATASET_NAME][-1]

# %%
from source.custom_classes.database_client import DatabaseClient

db_client = DatabaseClient()
db_client.connect()

# %% [markdown]
# ## Metric Visualizations

# %% [markdown]
# ### Overall Metrics

# %%
create_exp2_line_bands_for_diff_imputers(dataset_name=DATASET_NAME,
                                         model_name='rf_clf',
                                         metric_name='f1',
                                         db_client=db_client,
                                         with_band=False)
# Out:
# Prepared a plot for an MCAR train set
# Prepared a plot for an MAR train set
# Prepared a plot for an MNAR train set
# alt.VConcatChart(...)

# %%
create_exp2_line_bands_for_diff_imputers(dataset_name=DATASET_NAME,
                                         model_name='rf_clf',
                                         metric_name='Label_Stability',
                                         db_client=db_client,
                                         with_band=False)
# Out:
# Prepared a plot for an MCAR train set
# Prepared a plot for an MAR train set
# Prepared a plot for an MNAR train set
# alt.VConcatChart(...)

# %%
create_exp2_line_bands_for_diff_imputers(dataset_name=DATASET_NAME,
                                         model_name='rf_clf',
                                         metric_name='Aleatoric_Uncertainty',
                                         db_client=db_client,
                                         with_band=False)
# Out:
# Prepared a plot for an MCAR train set
# Prepared a plot for an MAR train set
# Prepared a plot for an MNAR train set
# alt.VConcatChart(...)

# %%
create_exp2_line_bands_for_diff_imputers(dataset_name=DATASET_NAME,
                                         model_name='rf_clf',
                                         metric_name='Std',
                                         db_client=db_client,
                                         with_band=False)
# Out:
# Prepared a plot for an MCAR train set
# Prepared a plot for an MAR train set
# Prepared a plot for an MNAR train set
# alt.VConcatChart(...)

# %% [markdown]
# ### Disparity Metrics

# %%
create_exp2_line_bands_for_diff_imputers(dataset_name=DATASET_NAME,
                                         model_name='rf_clf',
                                         metric_name='Selection_Rate_Difference',
                                         db_client=db_client,
                                         group=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
                                         with_band=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13472\1966639102.py in ?()
# ----> 1 create_exp2_line_bands_for_diff_imputers(dataset_name=DATASET_NAME,
#       2                                          model_name='rf_clf',
#       3                                          metric_name='Selection_Rate_Difference',
#       4                                          db_client=db_client,
#
# c:\RAI\data-cleaning-stability\source\visualizations\models_viz.py in ?(dataset_name, model_name, metric_name, db_client, group, ylim, with_band)
#     985 def create_exp2_line_bands_for_diff_imputers(dataset_name: str, model_name: str, metric_name: str, db_client,
#     986                                              group: str = 'overall', ylim=Undefined, with_band=True):
#     987     base_font_size = 20
#     988     mcar_base_chart1, mar_base_chart1, mnar_base_chart1 = (
# --> 989         get_exp2_line_bands_for_diff_imputers_and_single_eval_scenario(dataset_name=dataset_name,
#     990                                                                        evaluation_scenarios=['exp2_3_mcar1', 'exp2_3_mcar3', 'exp2_3_mcar5'],
#     991                                                                        train_set='MCAR',
#     992                                                                        model_name=model_name,
#
# c:\RAI\data-cleaning-stability\source\visualizations\models_viz.py in ?(dataset_name, evaluation_scenarios, model_name, metric_name, db_client, train_set, group, base_font_size, ylim, with_band)
#     921
#     922         models_metric_df = pd.concat([models_metric_df, scenario_models_metric_df])
#     923
#     924     models_metric_df = models_metric_df[models_metric_df['Model_Name'].isin([model_name, 'boost_clean'])]
# --> 925     models_metric_df['Train_Injection_Strategy'] = models_metric_df.apply(
#     926         lambda row: EVALUATION_SCENARIOS_CONFIG[row['Evaluation_Scenario']]['train_injection_scenario'][:-1],
#     927         axis=1
#     928     )
#
# c:\RAI\data-cleaning-stability\.venv\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    3966             self._setitem_frame(key, value)
#    3967         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    3968             self._setitem_array(key, value)
#    3969         elif isinstance(value, DataFrame):
# -> 3970             self._set_item_frame_value(key, value)
#    3971         elif (
#    3972             is_list_like(value)
#    3973             and not self.columns.is_unique
#
# c:\RAI\data-cleaning-stability\.venv\lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4121             self._set_item_mgr(key, arraylike)
#    4122             return
#    4123
#    4124         if len(value.columns) != 1:
# -> 4125             raise ValueError(
#    4126                 "Cannot set a DataFrame with multiple columns to the single "
#    4127                 f"column {key}"
#    4128             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column Train_Injection_Strategy

# %%
db_client.close()
