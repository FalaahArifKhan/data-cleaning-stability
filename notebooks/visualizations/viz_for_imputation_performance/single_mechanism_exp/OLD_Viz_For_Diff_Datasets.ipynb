# %% [markdown]
# # Visualizations for Different Datasets

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "data-cleaning-stability":
    os.chdir("../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability

# %%
from source.visualizations.imputers_viz import create_box_plots_for_diff_imputers_and_datasets
from configs.constants import (ACS_INCOME_DATASET, LAW_SCHOOL_DATASET, GERMAN_CREDIT_DATASET,
                               CARDIOVASCULAR_DISEASE_DATASET, BANK_MARKETING_DATASET, DIABETES_DATASET)

# %% [markdown]
# ## Initialize Configs

# %%
DATASETS_ALL_SENSITIVE_ATTRS = {
    ACS_INCOME_DATASET: ['SEX', 'RAC1P', 'SEX&RAC1P'],
    LAW_SCHOOL_DATASET: ['male', 'race', 'male&race'],
    GERMAN_CREDIT_DATASET: ['sex', 'age', 'sex&age'],
    CARDIOVASCULAR_DISEASE_DATASET: ['gender'],
    BANK_MARKETING_DATASET: ['age'],
    DIABETES_DATASET: ['Gender'],
}
DATASETS_SENSITIVE_ATTRS = {
    ACS_INCOME_DATASET: 'SEX&RAC1P',
    LAW_SCHOOL_DATASET: 'male&race',
    GERMAN_CREDIT_DATASET: 'sex',
    CARDIOVASCULAR_DISEASE_DATASET: 'gender',
    BANK_MARKETING_DATASET: 'age',
    DIABETES_DATASET: 'Gender',
}

# %%
from source.custom_classes.database_client import DatabaseClient

db_client = DatabaseClient()
db_client.connect()

# %% [markdown]
# ## Metric Visualizations

# %% [markdown]
# ### Overall Metrics

# %%
# Categorical
dataset_to_column_name = {
    DIABETES_DATASET: 'Family_Diabetes',
    GERMAN_CREDIT_DATASET: 'checking-account',
    ACS_INCOME_DATASET: 'MAR',
    LAW_SCHOOL_DATASET: 'tier',
    BANK_MARKETING_DATASET: 'job',
    CARDIOVASCULAR_DISEASE_DATASET: 'cholesterol',
}
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MNAR3',
                                                test_injection_scenario='MNAR3',
                                                metric_name='f1_score',
                                                dataset_to_column_name=dataset_to_column_name,
                                                db_client=db_client,
                                                without_dummy=False)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# alt.Chart(...)

# %%
# Numerical
dataset_to_column_name = {
    DIABETES_DATASET: 'SoundSleep',
    GERMAN_CREDIT_DATASET: 'duration',
    ACS_INCOME_DATASET: 'WKHP',
    LAW_SCHOOL_DATASET: 'zfygpa',
    BANK_MARKETING_DATASET: 'balance',
    CARDIOVASCULAR_DISEASE_DATASET: 'weight',
}
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MNAR3',
                                                test_injection_scenario='MNAR3',
                                                metric_name='rmse',
                                                dataset_to_column_name=dataset_to_column_name,
                                                db_client=db_client)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# alt.Chart(...)

# %%
# Categorical
dataset_to_column_name = {
    DIABETES_DATASET: 'Family_Diabetes',
    GERMAN_CREDIT_DATASET: 'checking-account',
    ACS_INCOME_DATASET: 'MAR',
    LAW_SCHOOL_DATASET: 'tier',
    BANK_MARKETING_DATASET: 'job',
    CARDIOVASCULAR_DISEASE_DATASET: 'cholesterol',
}
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MNAR3',
                                                test_injection_scenario='MNAR3',
                                                metric_name='kl_divergence_pred',
                                                dataset_to_column_name=dataset_to_column_name,
                                                db_client=db_client,
                                                without_dummy=False)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# alt.Chart(...)

# %%
# Numerical
dataset_to_column_name = {
    DIABETES_DATASET: 'SoundSleep',
    GERMAN_CREDIT_DATASET: 'duration',
    ACS_INCOME_DATASET: 'WKHP',
    LAW_SCHOOL_DATASET: 'zfygpa',
    BANK_MARKETING_DATASET: 'balance',
    CARDIOVASCULAR_DISEASE_DATASET: 'weight',
}
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MNAR3',
                                                test_injection_scenario='MNAR3',
                                                metric_name='kl_divergence_pred',
                                                dataset_to_column_name=dataset_to_column_name,
                                                db_client=db_client)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# alt.Chart(...)

# %% [markdown]
# ### Disparity Metrics

# %%
# Categorical
dataset_to_column_name = {
    DIABETES_DATASET: 'Family_Diabetes',
    GERMAN_CREDIT_DATASET: 'checking-account',
    ACS_INCOME_DATASET: 'MAR',
    LAW_SCHOOL_DATASET: 'tier',
    BANK_MARKETING_DATASET: 'job',
    CARDIOVASCULAR_DISEASE_DATASET: 'cholesterol',
}
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MNAR3',
                                                test_injection_scenario='MNAR3',
                                                metric_name='f1_score',
                                                dataset_to_column_name=dataset_to_column_name,
                                                dataset_to_group=DATASETS_SENSITIVE_ATTRS,
                                                db_client=db_client,
                                                without_dummy=False)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# alt.Chart(...)

# %%
# Numerical
dataset_to_column_name = {
    DIABETES_DATASET: 'SoundSleep',
    GERMAN_CREDIT_DATASET: 'duration',
    ACS_INCOME_DATASET: 'WKHP',
    LAW_SCHOOL_DATASET: 'zfygpa',
    BANK_MARKETING_DATASET: 'balance',
    CARDIOVASCULAR_DISEASE_DATASET: 'weight',
}
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MNAR3',
                                                test_injection_scenario='MNAR3',
                                                metric_name='rmse',
                                                dataset_to_column_name=dataset_to_column_name,
                                                dataset_to_group=DATASETS_SENSITIVE_ATTRS,
                                                db_client=db_client)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# alt.Chart(...)

# %%
# Categorical
dataset_to_column_name = {
    DIABETES_DATASET: 'Family_Diabetes',
    GERMAN_CREDIT_DATASET: 'checking-account',
    ACS_INCOME_DATASET: 'MAR',
    LAW_SCHOOL_DATASET: 'tier',
    BANK_MARKETING_DATASET: 'job',
    CARDIOVASCULAR_DISEASE_DATASET: 'cholesterol',
}
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MNAR3',
                                                test_injection_scenario='MNAR3',
                                                metric_name='kl_divergence_pred',
                                                dataset_to_column_name=dataset_to_column_name,
                                                dataset_to_group=DATASETS_SENSITIVE_ATTRS,
                                                db_client=db_client,
                                                without_dummy=False)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# alt.Chart(...)

# %%
# Numerical
dataset_to_column_name = {
    DIABETES_DATASET: 'SoundSleep',
    GERMAN_CREDIT_DATASET: 'duration',
    ACS_INCOME_DATASET: 'WKHP',
    LAW_SCHOOL_DATASET: 'zfygpa',
    BANK_MARKETING_DATASET: 'balance',
    CARDIOVASCULAR_DISEASE_DATASET: 'weight',
}
create_box_plots_for_diff_imputers_and_datasets(train_injection_scenario='MNAR3',
                                                test_injection_scenario='MNAR3',
                                                metric_name='kl_divergence_pred',
                                                dataset_to_column_name=dataset_to_column_name,
                                                dataset_to_group=DATASETS_SENSITIVE_ATTRS,
                                                db_client=db_client)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# alt.Chart(...)

# %%
db_client.close()
