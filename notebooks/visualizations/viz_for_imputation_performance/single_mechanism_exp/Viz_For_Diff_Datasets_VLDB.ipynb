# %% [markdown]
# # Visualizations for Different Datasets

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "data-cleaning-stability":
    os.chdir("../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability

# %%
from source.visualizations.imputers_viz import create_box_plots_for_diff_imputers_and_datasets_for_mixed_exp
from configs.constants import (ACS_INCOME_DATASET, ACS_EMPLOYMENT_DATASET, LAW_SCHOOL_DATASET, GERMAN_CREDIT_DATASET,
                               CARDIOVASCULAR_DISEASE_DATASET, BANK_MARKETING_DATASET, DIABETES_DATASET)

# %% [markdown]
# ## Initialize Configs

# %%
DATASETS_ALL_SENSITIVE_ATTRS = {
    ACS_INCOME_DATASET: ['SEX', 'RAC1P', 'SEX&RAC1P'],
    LAW_SCHOOL_DATASET: ['male', 'race', 'male&race'],
    GERMAN_CREDIT_DATASET: ['sex', 'age', 'sex&age'],
    CARDIOVASCULAR_DISEASE_DATASET: ['gender'],
    BANK_MARKETING_DATASET: ['age'],
    DIABETES_DATASET: ['Gender'],
    ACS_EMPLOYMENT_DATASET: ['SEX', 'RAC1P', 'SEX&RAC1P'],
}
DATASETS_SENSITIVE_ATTRS = {
    # ACS_INCOME_DATASET: 'SEX&RAC1P',
    # LAW_SCHOOL_DATASET: 'male&race',
    GERMAN_CREDIT_DATASET: 'sex',
    # CARDIOVASCULAR_DISEASE_DATASET: 'gender',
    # BANK_MARKETING_DATASET: 'age',
    DIABETES_DATASET: 'Gender',
    # ACS_EMPLOYMENT_DATASET: 'SEX&RAC1P',
}
DATASET_TO_COLUMN_NAME = {
    DIABETES_DATASET: {'cat': ['Family_Diabetes', 'PhysicallyActive', 'RegularMedicine'], 'num': ['SoundSleep']},
    GERMAN_CREDIT_DATASET: {'cat': ['checking-account', 'savings-account', 'employment-since'], 'num': ['duration', 'credit-amount']},
    ACS_INCOME_DATASET: {'cat': ['SCHL', 'MAR'], 'num': ['AGEP', 'WKHP']},
    LAW_SCHOOL_DATASET: {'cat': ['fam_inc', 'tier'], 'num': ['zfygpa', 'ugpa']},
    BANK_MARKETING_DATASET: {'cat': ['education', 'job'], 'num': ['balance', 'campaign']},
    CARDIOVASCULAR_DISEASE_DATASET: {'cat': ['cholesterol', 'gluc'], 'num': ['weight', 'height']},
    ACS_EMPLOYMENT_DATASET: {'cat': ['SCHL', 'DIS', 'MIL'], 'num': ['AGEP']},
}

# %%
from source.custom_classes.database_client import DatabaseClient, get_secrets_path

db_client = DatabaseClient()
db_client.connect()

# %% [markdown]
# ## Metric Visualizations

# %% [markdown]
# ### Overall Metrics

# %%
create_box_plots_for_diff_imputers_and_datasets_for_mixed_exp(train_injection_scenario='MCAR3',
                                                              test_injection_scenario='MCAR3',
                                                              metric_name='f1_score',
                                                              dataset_to_column_name=DATASET_TO_COLUMN_NAME,
                                                              db_client=db_client,
                                                              without_dummy=False)
# Out:
# metric_df[duplicates_mask]:
#      Dataset_Name Null_Imputer_Name  \
# 194       german          notmiwae
# 195       german          notmiwae
# 196       german          notmiwae
# 197       german          notmiwae
# 210       german          notmiwae
# 211       german          notmiwae
# 212       german          notmiwae
# 213       german          notmiwae
#
#                                    Null_Imputer_Params  Column_Type  \
# 194  {'n_latent': 18, 'n_hidden': 128, 'n_samples':...  categorical
# 195  {'n_latent': 18, 'n_hidden': 128, 'n_samples':...  categorical
# 196  {'n_latent': 18, 'n_hidden': 128, 'n_samples':...  categorical
# 197  {'n_latent': 18, 'n_hidden': 128, 'n_samples':...  categorical
# 210  {'n_latent': 18, 'n_hidden': 128, 'n_samples':...  categorical
# 211  {'n_latent': 18, 'n_hidden': 128, 'n_samples':...  categorical
# 212  {'n_latent': 18, 'n_hidden': 128, 'n_samples':...  categorical
# 213  {'n_latent': 18, 'n_hidden': 128, 'n_samples':...  categorical
#
#     Column_With_Nulls Subgroup  Sample_Size  Kl_Divergence_Pred  \
# 194  checking-account  overall           37            6.854001
# 195  checking-account  overall           12            8.720272
# 196  checking-account  overall           20            9.149109
# 197  checking-account  overall           40            4.244594
# 210  checking-account  overall           37            6.854001
# 211  checking-account  overall           12            8.483751
# 212  checking-account  overall           20            8.733220
# 213  checking-account  overall           40            3.742062
#
#      Kl_Divergence_Total  Rmse  ...                   Imputation_Guid  \
# 194             5.362292  None  ...  fe5dce37585da400ae7e2ae420646a5f
# 195             4.956897  None  ...  b8200c9ee8b3896e0eacf9bab3d18b39
# 196             4.977674  None  ...  d07754a1919ba84cdd45c807ec540959
# 197             5.041856  None  ...  fbdfe3e0effd31ca98c8b2a57e063f74
# 210             5.362292  None  ...  fe5dce37585da400ae7e2ae420646a5f
# 211             4.954034  None  ...  b8200c9ee8b3896e0eacf9bab3d18b39
# 212             4.974608  None  ...  d07754a1919ba84cdd45c807ec540959
# 213             5.043806  None  ...  fbdfe3e0effd31ca98c8b2a57e063f74
#
#                     Exp_Pipeline_Guid                          Session_Uuid  \
# 194  55da2148b5f1c5816b863dd9a137addb  19c2490a-c3d5-11ef-86d4-3cfdfe613f38
# 195  55da2148b5f1c5816b863dd9a137addb  19c2490a-c3d5-11ef-86d4-3cfdfe613f38
# 196  55da2148b5f1c5816b863dd9a137addb  19c2490a-c3d5-11ef-86d4-3cfdfe613f38
# 197  55da2148b5f1c5816b863dd9a137addb  19c2490a-c3d5-11ef-86d4-3cfdfe613f38
# 210  55da2148b5f1c5816b863dd9a137addb  519cc270-c3de-11ef-9f9e-3cfdfe613a30
# 211  55da2148b5f1c5816b863dd9a137addb  519cc270-c3de-11ef-9f9e-3cfdfe613a30
# 212  55da2148b5f1c5816b863dd9a137addb  519cc270-c3de-11ef-9f9e-3cfdfe613a30
# 213  55da2148b5f1c5816b863dd9a137addb  519cc270-c3de-11ef-9f9e-3cfdfe613a30
#
#     Evaluation_Scenario Experiment_Seed  Dataset_Part Runtime_In_Mins  \
# 194          exp1_mcar3             300   X_train_val        5.755111
# 195          exp1_mcar3             300  X_test_MCAR3        5.755111
# 196          exp1_mcar3             300   X_test_MAR3        5.755111
# 197          exp1_mcar3             300  X_test_MNAR3        5.755111
# 210          exp1_mcar3             300   X_train_val        5.363534
# 211          exp1_mcar3             300  X_test_MCAR3        5.363534
# 212          exp1_mcar3             300   X_test_MAR3        5.363534
# 213          exp1_mcar3             300  X_test_MNAR3        5.363534
#
#      Record_Create_Date_Time Tag  Null_Imputer_Params_Dct
# 194  2024-12-26 22:14:53.469  OK                      NaN
# 195  2024-12-26 22:14:53.489  OK                      NaN
# 196  2024-12-26 22:14:53.489  OK                      NaN
# 197  2024-12-26 22:14:53.489  OK                      NaN
# 210  2024-12-26 23:13:53.216  OK                      NaN
# 211  2024-12-26 23:13:53.332  OK                      NaN
# 212  2024-12-26 23:13:53.332  OK                      NaN
# 213  2024-12-26 23:13:53.332  OK                      NaN
#
# [8 rows x 23 columns]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 create_box_plots_for_diff_imputers_and_datasets_for_mixed_exp(train_injection_scenario='MCAR3',
#       2                                                               test_injection_scenario='MCAR3',
#       3                                                               metric_name='f1_score',
#       4                                                               dataset_to_column_name=DATASET_TO_COLUMN_NAME,
#       5                                                               db_client=db_client,
#       6                                                               without_dummy=False)
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/source/visualizations/imputers_viz.py:1121, in create_box_plots_for_diff_imputers_and_datasets_for_mixed_exp(train_injection_scenario, test_injection_scenario, dataset_to_column_name, metric_name, db_client, dataset_to_group, base_font_size, without_dummy, ylim)
#    1118     imputers_order = [t for t in imputers_order if t != ErrorRepairMethod.median_dummy.value]
#    1120 metric_name = '_'.join([c.capitalize() for c in metric_name.split('_')]) if 'equalized_odds' not in metric_name.lower() else metric_name
# -> 1121 to_plot, new_metric_name = get_data_for_box_plots_for_diff_imputers_and_datasets_for_mixed_exp(train_injection_scenario=train_injection_scenario,
#    1122                                                                                                test_injection_scenario=test_injection_scenario,
#    1123                                                                                                metric_name=metric_name,
#    1124                                                                                                dataset_to_column_name=dataset_to_column_name,
#    1125                                                                                                db_client=db_client,
#    1126                                                                                                dataset_to_group=dataset_to_group,
#    1127                                                                                                without_dummy=without_dummy)
#    1128 if dataset_to_group is not None and new_metric_name.lower() == 'rmse_difference':
#    1129     to_plot = to_plot.loc[~((to_plot['Dataset_Name'] == GERMAN_CREDIT_DATASET) & (to_plot[new_metric_name] > 100))]
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/source/visualizations/imputers_viz.py:1070, in get_data_for_box_plots_for_diff_imputers_and_datasets_for_mixed_exp(train_injection_scenario, test_injection_scenario, metric_name, db_client, dataset_to_column_name, dataset_to_group, without_dummy)
#    1068 for column_name in column_names:
#    1069     if group == 'overall':
# -> 1070         imputers_metric_df = get_imputers_metric_df(db_client=db_client,
#    1071                                                     dataset_name=dataset_name,
#    1072                                                     evaluation_scenario=evaluation_scenario,
#    1073                                                     column_name=column_name,
#    1074                                                     group=group)
#    1075         new_metric_name = metric_name
#    1077     else:
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/source/visualizations/imputers_viz.py:40, in get_imputers_metric_df(db_client, dataset_name, evaluation_scenario, column_name, group)
#      38 duplicates_mask = metric_df.duplicated(subset=['Imputation_Guid'], keep=False)
#      39 print('metric_df[duplicates_mask]:\n', metric_df[duplicates_mask])
# ---> 40 assert len(metric_df[duplicates_mask]) == 0, 'Metric df contains duplicates'
#      42 return metric_df
#
# AssertionError: Metric df contains duplicates

# %%
create_box_plots_for_diff_imputers_and_datasets_for_mixed_exp(train_injection_scenario='MCAR3',
                                                              test_injection_scenario='MCAR3',
                                                              metric_name='rmse',
                                                              dataset_to_column_name=DATASET_TO_COLUMN_NAME,
                                                              db_client=db_client,
                                                              without_dummy=False)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# alt.Chart(...)

# %%
create_box_plots_for_diff_imputers_and_datasets_for_mixed_exp(train_injection_scenario='MCAR3',
                                                              test_injection_scenario='MCAR3',
                                                              metric_name='kl_divergence_pred',
                                                              dataset_to_column_name=DATASET_TO_COLUMN_NAME,
                                                              db_client=db_client,
                                                              without_dummy=False)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# alt.Chart(...)

# %%
db_client.close()
