# %% [markdown]
# # Visualizations for No Shift

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "data-cleaning-stability":
    os.chdir("../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability

# %%
from source.visualizations.imputers_viz import create_exp2_line_bands_for_no_shift
from configs.constants import (ACS_INCOME_DATASET, LAW_SCHOOL_DATASET, GERMAN_CREDIT_DATASET,
                               CARDIOVASCULAR_DISEASE_DATASET, BANK_MARKETING_DATASET, DIABETES_DATASET)

# %% [markdown]
# ## Initialize Configs

# %%
DATASET_NAME = DIABETES_DATASET
DATASETS_SENSITIVE_ATTRS = {
    ACS_INCOME_DATASET: ['SEX', 'RAC1P', 'SEX&RAC1P'],
    LAW_SCHOOL_DATASET: ['male', 'race', 'male&race'],
    GERMAN_CREDIT_DATASET: ['sex', 'age', 'sex&age'],
    CARDIOVASCULAR_DISEASE_DATASET: ['gender'],
    BANK_MARKETING_DATASET: ['age'],
    DIABETES_DATASET: ['Gender'],
}
SENSITIVE_ATTR_FOR_DISPARITY_METRICS = DATASETS_SENSITIVE_ATTRS[DATASET_NAME][-1]

# %%
from source.custom_classes.database_client import DatabaseClient

db_client = DatabaseClient()
db_client.connect()

# %% [markdown]
# ## Metric Visualizations

# %% [markdown]
# ### Overall Metrics

# %%
create_exp2_line_bands_for_no_shift(dataset_name=DATASET_NAME,
                                    column_name='SoundSleep',
                                    metric_name='rmse',
                                    db_client=db_client)
# Out:
# Prepared a plot for an MCAR train set
# Prepared a plot for an MAR train set
# Prepared a plot for an MNAR train set
# alt.HConcatChart(...)

# %%
create_exp2_line_bands_for_no_shift(dataset_name=DATASET_NAME,
                                    column_name='PhysicallyActive',
                                    metric_name='f1_score',
                                    db_client=db_client,
                                    without_dummy=True)
# Out:
# Prepared a plot for an MCAR train set
# Prepared a plot for an MAR train set
# Prepared a plot for an MNAR train set
# alt.HConcatChart(...)

# %% [markdown]
# ### Disparity Metrics

# %%
create_exp2_line_bands_for_no_shift(dataset_name=DATASET_NAME,
                                    column_name='SoundSleep',
                                    metric_name='rmse',
                                    group='Gender',
                                    db_client=db_client,
                                    with_band=False)
# Out:
# Prepared a plot for an MCAR train set
# Prepared a plot for an MAR train set
# Prepared a plot for an MNAR train set
# alt.HConcatChart(...)

# %%
create_exp2_line_bands_for_no_shift(dataset_name=DATASET_NAME,
                                    column_name='PhysicallyActive',
                                    metric_name='f1_score',
                                    group='Gender',
                                    db_client=db_client,
                                    without_dummy=True,
                                    with_band=False)
# Out:
# Prepared a plot for an MCAR train set
# Prepared a plot for an MAR train set
# Prepared a plot for an MNAR train set
# alt.HConcatChart(...)

# %%
db_client.close()
