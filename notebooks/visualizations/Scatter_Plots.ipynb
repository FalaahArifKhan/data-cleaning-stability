# %% [markdown]
# # Scatter Plots

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "data-cleaning-stability":
    os.chdir("../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project

# %%
from source.visualizations.scatter_plots import create_scatter_plot
from configs.constants import (ACS_INCOME_DATASET, ACS_EMPLOYMENT_DATASET, LAW_SCHOOL_DATASET, GERMAN_CREDIT_DATASET,
                               CARDIOVASCULAR_DISEASE_DATASET, BANK_MARKETING_DATASET, DIABETES_DATASET)

# %% [markdown]
# ## Define global configs

# %%
from source.custom_classes.database_client import DatabaseClient, get_secrets_path

db_client_1 = DatabaseClient()
db_client_3 = DatabaseClient(secrets_path=get_secrets_path('secrets_3.env'))
db_client_1.connect()
db_client_3.connect()

# %%
DATASETS_ALL_SENSITIVE_ATTRS = {
    ACS_INCOME_DATASET: ['SEX', 'RAC1P', 'SEX&RAC1P'],
    LAW_SCHOOL_DATASET: ['male', 'race', 'male&race'],
    GERMAN_CREDIT_DATASET: ['sex', 'age', 'sex&age'],
    CARDIOVASCULAR_DISEASE_DATASET: ['gender'],
    BANK_MARKETING_DATASET: ['age'],
    DIABETES_DATASET: ['Gender'],
    ACS_EMPLOYMENT_DATASET: ['SEX', 'RAC1P', 'SEX&RAC1P'],
}

DATASETS_SENSITIVE_ATTRS = {
    ACS_INCOME_DATASET: 'SEX&RAC1P',
    LAW_SCHOOL_DATASET: 'male&race',
    GERMAN_CREDIT_DATASET: 'sex',
    CARDIOVASCULAR_DISEASE_DATASET: 'gender',
    BANK_MARKETING_DATASET: 'age',
    DIABETES_DATASET: 'Gender',
    ACS_EMPLOYMENT_DATASET: 'SEX&RAC1P',
}

DATASET_TO_COLUMN_NAME = {
    DIABETES_DATASET: {'cat': ['Family_Diabetes', 'PhysicallyActive', 'RegularMedicine'], 'num': ['SoundSleep']},
    GERMAN_CREDIT_DATASET: {'cat': ['checking-account', 'savings-account', 'employment-since'], 'num': ['duration', 'credit-amount']},
    ACS_INCOME_DATASET: {'cat': ['SCHL', 'MAR'], 'num': ['AGEP', 'WKHP']},
    LAW_SCHOOL_DATASET: {'cat': ['fam_inc', 'tier'], 'num': ['zfygpa', 'ugpa']},
    BANK_MARKETING_DATASET: {'cat': ['education', 'job'], 'num': ['balance', 'campaign']},
    CARDIOVASCULAR_DISEASE_DATASET: {'cat': ['cholesterol', 'gluc'], 'num': ['weight', 'height']},
    ACS_EMPLOYMENT_DATASET: {'cat': ['SCHL', 'DIS', 'MIL'], 'num': ['AGEP']},
}

# %% [markdown]
# ## Metric Visualizations

# %% [markdown]
# ### Overall Metrics

# %%
create_scatter_plot(missingness_types=[
                        {'train': 'MCAR3', 'test': 'MCAR3'},
                        {'train': 'MAR3', 'test': 'MAR3'},
                        {'train': 'MNAR3', 'test': 'MNAR3'},
                        {'train': 'mixed_exp', 'test': 'MCAR1 & MAR1 & MNAR1'},
                    ],
                    imputation_quality_metric_name='F1_Score',
                    model_performance_metric_name='F1',
                    dataset_to_column_name=DATASET_TO_COLUMN_NAME,
                    shape_by='Dataset_Name', # Dataset_Name or Model_Name
                    base_font_size=30,
                    db_client_1=db_client_1,
                    db_client_3=db_client_3)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extraction for {'train': 'MCAR3', 'test': 'MCAR3'} is completed
#
#
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extraction for {'train': 'MAR3', 'test': 'MAR3'} is completed
#
#
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extraction for {'train': 'MNAR3', 'test': 'MNAR3'} is completed
#
#
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extraction for {'train': 'mixed_exp', 'test': 'MCAR1 & MAR1 & MNAR1'} is completed
# alt.FacetChart(...)

# %%
create_scatter_plot(missingness_types=[
                        {'train': 'MCAR3', 'test': 'MCAR3'},
                        {'train': 'MAR3', 'test': 'MAR3'},
                        {'train': 'MNAR3', 'test': 'MNAR3'},
                        {'train': 'mixed_exp', 'test': 'MCAR1 & MAR1 & MNAR1'},
                    ],
                    imputation_quality_metric_name='RMSE',
                    model_performance_metric_name='F1',
                    dataset_to_column_name=DATASET_TO_COLUMN_NAME,
                    shape_by='Dataset_Name', # Dataset_Name or Model_Name
                    base_font_size=30,
                    db_client_1=db_client_1,
                    db_client_3=db_client_3)
# Out:
# [autoreload of source.visualizations.imputers_viz failed: Traceback (most recent call last):
#   File "/Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/dns/query.py", line 513, in _udp_recv
#     return sock.recvfrom(max_size)
# BlockingIOError: [Errno 35] Resource temporarily unavailable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 850, in exec_module
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/source/visualizations/imputers_viz.py", line 18, in <module>
#     DB_CLIENT_2.connect()
#   File "/Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/source/custom_classes/database_client.py", line 26, in connect
#     self.client = MongoClient(self.connection_string, tlsCAFile=certifi.where())
#   File "/Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/mongo_client.py", line 736, in __init__
#     res = uri_parser.parse_uri(
#   File "/Users/denys_herasymuk/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/uri_parser.py", line 542, in parse_uri
#     nodes = dns_resolver.get_hosts()
# KeyboardInterrupt
# ]
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# new_imputation_quality_metric: Rmse
# imputation_quality_metrics_sub_df.head():
#    Dataset_Name Null_Imputer_Name Evaluation_Scenario  Experiment_Seed  \
# 0         bank            automl          exp1_mcar3              100
# 1         bank            automl          exp1_mcar3              200
# 2         bank            automl          exp1_mcar3              300
# 3         bank            automl          exp1_mcar3              400
# 4         bank            automl          exp1_mcar3              500
#
#    Dataset_Part  Sample_Size  Kl_Divergence_Pred  Kl_Divergence_Total  \
# 0  X_test_MCAR3        561.5                 NaN             0.002035
# 1  X_test_MCAR3        610.5                 NaN                  NaN
# 2  X_test_MCAR3        616.0                 NaN                  NaN
# 3  X_test_MCAR3        596.0                 NaN             0.002407
# 4  X_test_MCAR3        608.0                 NaN                  NaN
#
#        Rmse  Runtime_In_Mins  Null_Imputer_Params_Dct
# 0  0.975608       259.697079                      NaN
# 1  0.968988       240.951897                      NaN
# 2  0.948218       219.435821                      NaN
# 3  0.972816       231.788785                      NaN
# 4  0.978680       254.405097                      NaN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 create_scatter_plot(missingness_types=[
#       2                         {'train': 'MCAR3', 'test': 'MCAR3'},
#       3                         {'train': 'MAR3', 'test': 'MAR3'},
#       4                         {'train': 'MNAR3', 'test': 'MNAR3'},
#       5                         {'train': 'mixed_exp', 'test': 'MCAR1 & MAR1 & MNAR1'},
#       6                     ],
#       7                     imputation_quality_metric_name='RMSE',
#       8                     model_performance_metric_name='F1',
#       9                     dataset_to_column_name=DATASET_TO_COLUMN_NAME,
#      10                     shape_by='Dataset_Name', # Dataset_Name or Model_Name
#      11                     # dataset_to_group=DATASETS_SENSITIVE_ATTRS,
#      12                     base_font_size=30,
#      13                     db_client_1=db_client_1,
#      14                     db_client_3=db_client_3)
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/source/visualizations/scatter_plots.py:114, in create_scatter_plot(missingness_types, dataset_to_column_name, imputation_quality_metric_name, model_performance_metric_name, shape_by, db_client_1, db_client_3, dataset_to_group, base_font_size, without_dummy, ylim)
#     111 imputation_quality_metric_name = imputation_quality_metric_name.lower().replace('_difference', '')
#     113 # Read the data
# --> 114 merged_df, new_imputation_quality_metric = get_scatter_plot_data(missingness_types=missingness_types,
#     115                                                                  dataset_to_column_name=dataset_to_column_name,
#     116                                                                  imputation_quality_metric_name=imputation_quality_metric_name,
#     117                                                                  extended_imputation_quality_metric_name=extended_imputation_quality_metric_name,
#     118                                                                  model_performance_metric_name=model_performance_metric_name,
#     119                                                                  db_client_1=db_client_1,
#     120                                                                  db_client_3=db_client_3,
#     121                                                                  dataset_to_group=dataset_to_group,
#     122                                                                  without_dummy=without_dummy)
#     123 print("new_imputation_quality_metric:", new_imputation_quality_metric)
#     124 print("merged_df.head():\n", merged_df.head())
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/source/visualizations/scatter_plots.py:36, in get_scatter_plot_data(missingness_types, dataset_to_column_name, imputation_quality_metric_name, extended_imputation_quality_metric_name, model_performance_metric_name, db_client_1, db_client_3, dataset_to_group, without_dummy)
#      33 print("new_imputation_quality_metric:", new_imputation_quality_metric)
#      34 print("imputation_quality_metrics_sub_df.head():\n", imputation_quality_metrics_sub_df.head())
# ---> 36 model_performance_metrics_sub_df = get_data_for_box_plots_for_diff_imputers_and_datasets(train_injection_scenario=train_injection_scenario,
#      37                                                                                          test_injection_scenario=test_injection_scenario,
#      38                                                                                          metric_name=model_performance_metric_name,
#      39                                                                                          db_client=db_client,
#      40                                                                                          dataset_to_group=dataset_to_group)
#      42 imputation_quality_metrics_sub_df['Missingness_Type'] = train_injection_scenario + ' - ' + test_injection_scenario
#      43 model_performance_metrics_sub_df['Missingness_Type'] = train_injection_scenario + ' - ' + test_injection_scenario
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/source/visualizations/model_metrics_extraction_for_viz.py:60, in get_data_for_box_plots_for_diff_imputers_and_datasets(train_injection_scenario, test_injection_scenario, metric_name, db_client, dataset_to_group)
#      57 model_name = dataset_to_model_name_dct[dataset_name]
#      59 if group == 'overall':
# ---> 60     models_metric_df = get_models_metric_df(db_client=db_client,
#      61                                             dataset_name=dataset_name,
#      62                                             evaluation_scenario=evaluation_scenario,
#      63                                             metric_name=metric_name,
#      64                                             group=group)
#      65 else:
#      66     overall_metric = get_overall_metric_from_disparity_metric(disparity_metric=metric_name)
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/source/visualizations/model_metrics_extraction_for_viz.py:274, in get_models_metric_df(db_client, dataset_name, evaluation_scenario, metric_name, group)
#     265 def get_models_metric_df(db_client, dataset_name: str, evaluation_scenario: str,
#     266                          metric_name: str, group: str):
#     267     query = {
#     268         'dataset_name': dataset_name,
#     269         'evaluation_scenario': evaluation_scenario,
#    (...)
#     272         'tag': 'OK',
#     273     }
# --> 274     metric_df = db_client.read_metric_df_from_db(collection_name=EXP_COLLECTION_NAME,
#     275                                                  query=query)
#     276     # if db_client.db_name == 'data_cleaning_stability_2':
#     277     if db_client.db_name == 'data_cleaning_stability_3':
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/source/custom_classes/database_client.py:62, in DatabaseClient.read_metric_df_from_db(self, collection_name, query)
#      61 def read_metric_df_from_db(self, collection_name: str, query: dict):
# ---> 62     records = self.execute_read_query(query=query,
#      63                                       collection_name=collection_name)
#      64     metric_df = pd.DataFrame(records)
#      66     # Capitalize column names to be consistent across the whole library
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/source/custom_classes/database_client.py:39, in DatabaseClient.execute_read_query(self, collection_name, query)
#      37 cursor = collection.find(query)
#      38 records = []
# ---> 39 for record in cursor:
#      40     del record['_id']
#      41     records.append(record)
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/cursor.py:1248, in Cursor.next(self)
#    1246 if self.__empty:
#    1247     raise StopIteration
# -> 1248 if len(self.__data) or self._refresh():
#    1249     return self.__data.popleft()
#    1250 else:
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/cursor.py:1188, in Cursor._refresh(self)
#    1173     # Exhaust cursors don't send getMore messages.
#    1174     g = self._getmore_class(
#    1175         self.__dbname,
#    1176         self.__collname,
#    (...)
#    1186         self.__comment,
#    1187     )
# -> 1188     self.__send_message(g)
#    1190 return len(self.__data)
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/cursor.py:1052, in Cursor.__send_message(self, operation)
#    1049     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1051 try:
# -> 1052     response = client._run_operation(
#    1053         operation, self._unpack_response, address=self.__address
#    1054     )
#    1055 except OperationFailure as exc:
#    1056     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1057         # Don't send killCursors because the cursor is already closed.
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/mongo_client.py:1330, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1325     operation.reset()  # Reset op in case of retry.
#    1326     return server.run_operation(
#    1327         sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1328     )
# -> 1330 return self._retryable_read(
#    1331     _cmd,
#    1332     operation.read_preference,
#    1333     operation.session,
#    1334     address=address,
#    1335     retryable=isinstance(operation, message._Query),
#    1336 )
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/mongo_client.py:1448, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1446             assert last_error is not None
#    1447             raise last_error
# -> 1448         return func(session, server, sock_info, read_pref)
#    1449 except ServerSelectionTimeoutError:
#    1450     if retrying:
#    1451         # The application may think the write was never attempted
#    1452         # if we raise ServerSelectionTimeoutError on the retry
#    1453         # attempt. Raise the original exception instead.
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/mongo_client.py:1326, in MongoClient._run_operation.<locals>._cmd(session, server, sock_info, read_preference)
#    1324 def _cmd(session, server, sock_info, read_preference):
#    1325     operation.reset()  # Reset op in case of retry.
# -> 1326     return server.run_operation(
#    1327         sock_info, operation, read_preference, self._event_listeners, unpack_res
#    1328     )
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/server.py:115, in Server.run_operation(self, sock_info, operation, read_preference, listeners, unpack_res)
#     113 else:
#     114     sock_info.send_message(data, max_doc_size)
# --> 115     reply = sock_info.receive_message(request_id)
#     117 # Unpack and check for command errors.
#     118 if use_cmd:
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/pool.py:821, in SocketInfo.receive_message(self, request_id)
#     819     return receive_message(self, request_id, self.max_message_size)
#     820 except BaseException as error:
# --> 821     self._raise_connection_failure(error)
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/pool.py:819, in SocketInfo.receive_message(self, request_id)
#     814 """Receive a raw BSON message or raise ConnectionFailure.
#     815
#     816 If any exception is raised, the socket is closed.
#     817 """
#     818 try:
# --> 819     return receive_message(self, request_id, self.max_message_size)
#     820 except BaseException as error:
#     821     self._raise_connection_failure(error)
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/network.py:238, in receive_message(sock_info, request_id, max_message_size)
#     236     data = decompress(_receive_data_on_socket(sock_info, length - 25, deadline), compressor_id)
#     237 else:
# --> 238     data = _receive_data_on_socket(sock_info, length - 16, deadline)
#     240 try:
#     241     unpack_reply = _UNPACK_REPLY[op_code]
#
# File ~/Research/NYU/ML_Lifecycle_Project/Code/data-cleaning-stability/vldb_venv/lib/python3.9/site-packages/pymongo/network.py:299, in _receive_data_on_socket(sock_info, length, deadline)
#     297     if _csot.get_timeout():
#     298         sock_info.set_socket_timeout(max(deadline - time.monotonic(), 0))
# --> 299     chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     300 except BLOCKING_IO_ERRORS:
#     301     raise socket.timeout("timed out")
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
create_scatter_plot(missingness_types=[
                        {'train': 'MCAR3', 'test': 'MCAR3'},
                        {'train': 'MAR3', 'test': 'MAR3'},
                        {'train': 'MNAR3', 'test': 'MNAR3'},
                        {'train': 'mixed_exp', 'test': 'MCAR1 & MAR1 & MNAR1'},
                    ],
                    imputation_quality_metric_name='kl_divergence_pred',
                    model_performance_metric_name='F1',
                    dataset_to_column_name=DATASET_TO_COLUMN_NAME,
                    shape_by='Dataset_Name', # Dataset_Name or Model_Name
                    base_font_size=30,
                    db_client_1=db_client_1,
                    db_client_3=db_client_3)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# new_imputation_quality_metric: Kl_Divergence_Pred
# imputation_quality_metrics_sub_df.head():
#    Dataset_Name Null_Imputer_Name Evaluation_Scenario  Experiment_Seed  \
# 0         bank            automl          exp1_mcar3              100
# 1         bank            automl          exp1_mcar3              200
# 2         bank            automl          exp1_mcar3              300
# 3         bank            automl          exp1_mcar3              400
# 4         bank            automl          exp1_mcar3              500
#
#    Dataset_Part  Sample_Size  Kl_Divergence_Pred  Kl_Divergence_Total  \
# 0  X_test_MCAR3        621.0            1.941451             0.001093
# 1  X_test_MCAR3        571.0            2.919792             0.001259
# 2  X_test_MCAR3        574.5            1.918285             0.000813
# 3  X_test_MCAR3        592.5            1.680980             0.000946
# 4  X_test_MCAR3        578.5            0.295556             0.000444
#
#    Runtime_In_Mins  Null_Imputer_Params_Dct
# 0       259.697079                      NaN
# 1       240.951897                      NaN
# 2       219.435821                      NaN
# 3       231.788785                      NaN
# 4       254.405097                      NaN
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extraction for {'train': 'MCAR3', 'test': 'MCAR3'} is completed
#
#
# new_imputation_quality_metric: Kl_Divergence_Pred
# merged_df.head():
#    Dataset_Name Null_Imputer_Name Evaluation_Scenario Missingness_Type  \
# 0         bank            automl          exp1_mcar3    MCAR3 - MCAR3
# 1         bank            automl          exp1_mcar3    MCAR3 - MCAR3
# 2         bank           datawig          exp1_mcar3    MCAR3 - MCAR3
# 3         bank           datawig          exp1_mcar3    MCAR3 - MCAR3
# 4         bank          deletion          exp1_mcar3    MCAR3 - MCAR3
#
#    Experiment_Seed  Sample_Size  Kl_Divergence_Pred  Kl_Divergence_Total  \
# 0            350.0   583.583333            1.764643             0.000914
# 1            350.0   583.583333            1.764643             0.000914
# 2            350.0   583.583333            1.734502             0.000926
# 3            350.0   583.583333            1.734502             0.000926
# 4            350.0   592.625000           13.259313             0.004719
#
#    Runtime_In_Mins  Null_Imputer_Params_Dct Model_Name        F1   F1_Line  \
# 0       236.719697                      NaN   lgbm_clf  0.318323  0.296159
# 1       236.719697                      NaN   lgbm_clf  0.318323  0.947805
# 2        77.571837                      NaN   lgbm_clf  0.310582  0.296159
# 3        77.571837                      NaN   lgbm_clf  0.310582  0.947805
# 4         0.000816                      NaN   lgbm_clf  0.296159  0.296159
#
#    Kl_Divergence_Pred_Line
# 0                 0.005283
# 1                26.148401
# 2                 0.005283
# 3                26.148401
# 4                 0.005283
# Num nulls: Dataset_Name                 0
# Null_Imputer_Name            0
# Evaluation_Scenario          0
# Missingness_Type             0
# Experiment_Seed              0
# Sample_Size                  0
# Kl_Divergence_Pred           0
# Kl_Divergence_Total          0
# Runtime_In_Mins              0
# Null_Imputer_Params_Dct    126
# Model_Name                   0
# F1                           0
# F1_Line                      0
# Kl_Divergence_Pred_Line      0
# dtype: int64
# alt.FacetChart(...)

# %% [markdown]
# ### Disparity Metrics

# %%
create_scatter_plot(missingness_types=[
                        {'train': 'MCAR3', 'test': 'MCAR3'},
                        # {'train': 'MAR3', 'test': 'MAR3'},
                        # {'train': 'MNAR3', 'test': 'MNAR3'},
                        # {'train': 'mixed_exp', 'test': 'MCAR1 & MAR1 & MNAR1'},
                    ],
                    imputation_quality_metric_name='f1_score_difference',
                    model_performance_metric_name='Equalized_Odds_TPR',
                    dataset_to_column_name=DATASET_TO_COLUMN_NAME,
                    dataset_to_group=DATASETS_SENSITIVE_ATTRS,
                    shape_by='Dataset_Name', # Dataset_Name or Model_Name
                    base_font_size=30,
                    db_client_1=db_client_1,
                    db_client_3=db_client_3)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# new_imputation_quality_metric: F1_Score_Difference
# imputation_quality_metrics_sub_df.head():
#    Dataset_Name Null_Imputer_Name Evaluation_Scenario  Experiment_Seed  \
# 0         bank            automl          exp1_mcar3              100
# 1         bank            automl          exp1_mcar3              200
# 2         bank            automl          exp1_mcar3              300
# 3         bank            automl          exp1_mcar3              400
# 4         bank            automl          exp1_mcar3              500
#
#    Dataset_Part  F1_Score_dis  F1_Score_priv  F1_Score_Difference
# 0  X_test_MCAR3      0.439935       0.558869            -0.118934
# 1  X_test_MCAR3      0.492725       0.563010            -0.070286
# 2  X_test_MCAR3      0.416667       0.513057            -0.096390
# 3  X_test_MCAR3      0.416149       0.552526            -0.136377
# 4  X_test_MCAR3      0.406703       0.563677            -0.156974
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extraction for {'train': 'MCAR3', 'test': 'MCAR3'} is completed
# alt.FacetChart(...)

# %%
create_scatter_plot(missingness_types=[
                        {'train': 'MCAR3', 'test': 'MCAR3'},
                        # {'train': 'MAR3', 'test': 'MAR3'},
                        # {'train': 'MNAR3', 'test': 'MNAR3'},
                        # {'train': 'mixed_exp', 'test': 'MCAR1 & MAR1 & MNAR1'},
                    ],
                    imputation_quality_metric_name='rmse_difference',
                    model_performance_metric_name='Equalized_Odds_TPR',
                    dataset_to_column_name=DATASET_TO_COLUMN_NAME,
                    dataset_to_group=DATASETS_SENSITIVE_ATTRS,
                    shape_by='Dataset_Name', # Dataset_Name or Model_Name
                    base_font_size=30,
                    db_client_1=db_client_1,
                    db_client_3=db_client_3)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extraction for {'train': 'MCAR3', 'test': 'MCAR3'} is completed
# alt.FacetChart(...)

# %%
create_scatter_plot(missingness_types=[
                        {'train': 'MCAR3', 'test': 'MCAR3'},
                        # {'train': 'MAR3', 'test': 'MAR3'},
                        # {'train': 'MNAR3', 'test': 'MNAR3'},
                        # {'train': 'mixed_exp', 'test': 'MCAR1 & MAR1 & MNAR1'},
                    ],
                    imputation_quality_metric_name='kl_divergence_pred_difference',
                    model_performance_metric_name='Equalized_Odds_TPR',
                    dataset_to_column_name=DATASET_TO_COLUMN_NAME,
                    dataset_to_group=DATASETS_SENSITIVE_ATTRS,
                    shape_by='Dataset_Name', # Dataset_Name or Model_Name
                    base_font_size=30,
                    db_client_1=db_client_1,
                    db_client_3=db_client_3)
# Out:
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extracted data for german
# Extracted data for bank
# Extracted data for heart
# Extracted data for diabetes
# Extracted data for law_school
# Extracted data for folk
# Extracted data for folk_emp
# Extraction for {'train': 'MCAR3', 'test': 'MCAR3'} is completed
# alt.FacetChart(...)
